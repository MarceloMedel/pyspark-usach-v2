# %%
import socket
import time
import json

def start_server(file_path, host, port, delay):
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as server_socket:
        server_socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
        server_socket.bind((host, port))
        server_socket.listen(1)
        print(f"Server listening on {host}:{port}")
        conn, addr = server_socket.accept()
        with conn:
            print(f"Connected by {addr}") 
            with open(file_path, 'r') as file: 
                json_file = json.load(file) 
                for line in json_file:
                    conn.sendall((json.dumps(line) + '\n').encode())
                    print(f"registro enviado: {line}") 
                    time.sleep(delay) 
            print("File data sent, closing connection.")
            conn.close()

host = 'localhost'
port = 9999
delay = 1
file_path = 'data/streaming/streaming_sample.json'

start_server(file_path, host, port, delay)
# Out:
# Server listening on localhost:9999
# Connected by ('127.0.0.1', 58582)
# registro enviado: {'ts': '2017-01-28T14:35:07Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 277840, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Show Me How to Live', 'master_metadata_album_artist_name': 'Audioslave', 'master_metadata_album_album_name': 'Audioslave', 'spotify_track_uri': 'spotify:track:4j4GOtjzdDux57p39vJPnz', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485613394490, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T14:40:01Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 279333, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Gasoline', 'master_metadata_album_artist_name': 'Audioslave', 'master_metadata_album_album_name': 'Audioslave', 'spotify_track_uri': 'spotify:track:6zeI0rAxevXdtmwVHyCQdx', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485614093978, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T14:44:10Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 249400, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'What You Are', 'master_metadata_album_artist_name': 'Audioslave', 'master_metadata_album_album_name': 'Audioslave', 'spotify_track_uri': 'spotify:track:5D4Mi9lu1f7MCkSFbeaZqJ', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485614400206, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T14:49:04Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 293960, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Like a Stone', 'master_metadata_album_artist_name': 'Audioslave', 'master_metadata_album_album_name': 'Audioslave', 'spotify_track_uri': 'spotify:track:2MrWu3Gt6ucsOHC6eE8oLV', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485614649671, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T14:53:51Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 263200, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Set It Off', 'master_metadata_album_artist_name': 'Audioslave', 'master_metadata_album_album_name': 'Audioslave', 'spotify_track_uri': 'spotify:track:0OL0iYmqNBZnufCKGgNpH7', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485614943660, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T15:00:02Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 343400, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Shadow on the Sun', 'master_metadata_album_artist_name': 'Audioslave', 'master_metadata_album_album_name': 'Audioslave', 'spotify_track_uri': 'spotify:track:1NIv7bG744T9PYF9oqEwuJ', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485615230427, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T15:44:41Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 334906, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'I Am the Highway', 'master_metadata_album_artist_name': 'Audioslave', 'master_metadata_album_album_name': 'Audioslave', 'spotify_track_uri': 'spotify:track:72ZG3Ay0unYpQFaYyYiaKX', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485615600639, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T15:45:40Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 58409, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Exploder', 'master_metadata_album_artist_name': 'Audioslave', 'master_metadata_album_album_name': 'Audioslave', 'spotify_track_uri': 'spotify:track:5CeRB3DKhs1orauuBd64qF', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485618280420, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T15:49:50Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 249521, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Harder Than You Think', 'master_metadata_album_artist_name': 'Public Enemy', 'master_metadata_album_album_name': 'How You Sell Soul to a Soulless People Who Sold Their Soul?', 'spotify_track_uri': 'spotify:track:5YpZh8wfS4moRBk0ijNcXr', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'clickrow', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485618340134, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T15:54:35Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 282640, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Fight The Power', 'master_metadata_album_artist_name': 'Public Enemy', 'master_metadata_album_album_name': 'Fear Of A Black Planet', 'spotify_track_uri': 'spotify:track:26zWdOUpB6P9E9OtQQc0qp', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485618589237, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T15:59:36Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 286200, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'He Got Game', 'master_metadata_album_artist_name': 'Public Enemy', 'master_metadata_album_album_name': 'He Got Game', 'spotify_track_uri': 'spotify:track:7aRGb3vZGMLNpK2PEdUjdA', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485618872287, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T16:08:11Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 321560, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': "Can't Truss It", 'master_metadata_album_artist_name': 'Public Enemy', 'master_metadata_album_album_name': 'Apocalypse 91… The Enemy Strikes Black', 'spotify_track_uri': 'spotify:track:54CT521CBzQ0HGOjs7FkKV', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485619174529, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T16:09:50Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 97559, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Bring the Noise', 'master_metadata_album_artist_name': 'Public Enemy', 'master_metadata_album_album_name': 'Made In Chicago', 'spotify_track_uri': 'spotify:track:6Le4D98HYcYw23Ik2y0G5V', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485619690535, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T16:14:09Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 260000, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': "Shut 'Em Up", 'master_metadata_album_artist_name': 'The Prodigy', 'master_metadata_album_album_name': 'The Day Is My Enemy (Expanded Edition)', 'spotify_track_uri': 'spotify:track:6uz3fmds1X0YvxFp9KOmFs', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485619789483, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T16:17:55Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 226040, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Bring The Noise', 'master_metadata_album_artist_name': 'Public Enemy', 'master_metadata_album_album_name': 'It Takes A Nation Of Millions To Hold Us Back', 'spotify_track_uri': 'spotify:track:2bKNjAVYsbJ35N2OXFfAxO', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485620048572, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:28:21Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 53084, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': "Don't Believe The Hype", 'master_metadata_album_artist_name': 'Public Enemy', 'master_metadata_album_album_name': 'It Takes A Nation Of Millions To Hold Us Back', 'spotify_track_uri': 'spotify:track:0PLbcZUbVqhfHmRKU4SiMK', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485620274933, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:12Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 230968, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Straight Outta Compton - Extended Mix / Edit', 'master_metadata_album_artist_name': 'N.W.A.', 'master_metadata_album_album_name': 'Greatest Hits', 'spotify_track_uri': 'spotify:track:3eGBESLT08agei7veoLLlz', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'clickrow', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628100619, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:15Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 1648, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Hello', 'master_metadata_album_artist_name': 'Adele', 'master_metadata_album_album_name': 'Hello', 'spotify_track_uri': 'spotify:track:0ENSn4fwAbCGeFGVUbXEU3', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'clickrow', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628332165, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:16Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 1021, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Sacar la Voz', 'master_metadata_album_artist_name': 'Ana Tijoux', 'master_metadata_album_album_name': 'La Bala', 'spotify_track_uri': 'spotify:track:1tR0tdHtTapWhGkUAEfgVR', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628334241, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:17Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 766, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'In This World', 'master_metadata_album_artist_name': 'Moby', 'master_metadata_album_album_name': '18', 'spotify_track_uri': 'spotify:track:5cGObTpStnmILli38m57tj', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackerror', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628335311, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:18Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 859, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Walking in My Shoes', 'master_metadata_album_artist_name': 'Depeche Mode', 'master_metadata_album_album_name': 'Songs of Faith and Devotion (Deluxe)', 'spotify_track_uri': 'spotify:track:2Y7ndoyiIm0IaFJa13gV3H', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628336620, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:20Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 0, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Paradise Circus', 'master_metadata_album_artist_name': 'Massive Attack', 'master_metadata_album_album_name': 'Heligoland', 'spotify_track_uri': 'spotify:track:2BndJYJQ17UcEeUFJP5JmY', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628338221, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:20Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 0, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Walking in My Shoes', 'master_metadata_album_artist_name': 'Depeche Mode', 'master_metadata_album_album_name': 'Songs of Faith and Devotion (Deluxe)', 'spotify_track_uri': 'spotify:track:2Y7ndoyiIm0IaFJa13gV3H', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'backbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628339400, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:21Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 0, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Paradise Circus', 'master_metadata_album_artist_name': 'Massive Attack', 'master_metadata_album_album_name': 'Heligoland', 'spotify_track_uri': 'spotify:track:2BndJYJQ17UcEeUFJP5JmY', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628339888, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:22Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 0, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Every Breath You Take - Remastered 2003', 'master_metadata_album_artist_name': 'The Police', 'master_metadata_album_album_name': 'Synchronicity', 'spotify_track_uri': 'spotify:track:5C0LFQARavkPpn7JgA4sLk', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628340271, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:23Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 0, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Every You Every Me', 'master_metadata_album_artist_name': 'Placebo', 'master_metadata_album_album_name': "Without You I'm Nothing", 'spotify_track_uri': 'spotify:track:3tRv4ZYZimrL27flnjgeR6', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628341539, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:28Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 3018, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Puente', 'master_metadata_album_artist_name': 'Gustavo Cerati', 'master_metadata_album_album_name': 'Bocanada', 'spotify_track_uri': 'spotify:track:6gwaa6ElIixNTvu6RwkMyo', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628342743, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:32:29Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 325, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'With Or Without You - Remastered', 'master_metadata_album_artist_name': 'U2', 'master_metadata_album_album_name': 'The Joshua Tree', 'spotify_track_uri': 'spotify:track:4kAJawkLZj4Q7N5521ofP6', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628347649, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:36:55Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 256946, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': "You Know I'm No Good", 'master_metadata_album_artist_name': 'Amy Winehouse', 'master_metadata_album_album_name': 'Back To Black', 'spotify_track_uri': 'spotify:track:4SyowQi18ym4zJGJDBnsTj', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628349003, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:41:52Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 230760, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Use Somebody', 'master_metadata_album_artist_name': 'Kings of Leon', 'master_metadata_album_album_name': 'Only By The Night', 'spotify_track_uri': 'spotify:track:5VGlqQANWDKJFl0MBG3sg2', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628615079, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:45:28Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 215266, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Everyday Is Like Sunday - 2011 Remaster', 'master_metadata_album_artist_name': 'Morrissey', 'master_metadata_album_album_name': 'Viva Hate', 'spotify_track_uri': 'spotify:track:0egYMfS7hjEneR86a9K61w', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485628912023, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:45:54Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 25097, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Blackfield', 'master_metadata_album_artist_name': 'Blackfield', 'master_metadata_album_album_name': 'Blackfield', 'spotify_track_uri': 'spotify:track:71lboXdN743zXxlfrsOSC1', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629127829, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:45:56Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 1091, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'First Of The Gang To Die - Remastered', 'master_metadata_album_artist_name': 'Morrissey', 'master_metadata_album_album_name': 'Morrissey Greatest Hits', 'spotify_track_uri': 'spotify:track:3kjg4p8oHDOFzqK0b75LzU', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629154309, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:45:57Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 1160, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Saturnine', 'master_metadata_album_artist_name': 'The Gathering', 'master_metadata_album_album_name': 'If_then_else', 'spotify_track_uri': 'spotify:track:5eJ0DG8hnSZkSixPVQvNDl', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629155415, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:45:59Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 1207, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Paper Waves', 'master_metadata_album_artist_name': 'The Gathering', 'master_metadata_album_album_name': 'Disclosure', 'spotify_track_uri': 'spotify:track:761BO4WWcxjX9qztLp2aRa', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629156859, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:46:00Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 0, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Teargas', 'master_metadata_album_artist_name': 'Katatonia', 'master_metadata_album_album_name': 'Last Fair Deal Gone Down - 10th Anniversay Edition', 'spotify_track_uri': 'spotify:track:2Bskmd975kL0Vb25hFYhGm', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629158534, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:46:01Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 0, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Joga', 'master_metadata_album_artist_name': 'Björk', 'master_metadata_album_album_name': 'Homogenic', 'spotify_track_uri': 'spotify:track:4tp6vyJpXa0Vr73IYerX28', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629159491, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:50:50Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 288466, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Modern Love - 1999 Remaster', 'master_metadata_album_artist_name': 'David Bowie', 'master_metadata_album_album_name': "Let's Dance", 'spotify_track_uri': 'spotify:track:7LyIoUsiMtelB1I0I4drEF', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629160498, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:55:01Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 250160, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Precious', 'master_metadata_album_artist_name': 'Depeche Mode', 'master_metadata_album_album_name': 'Playing The Angel', 'spotify_track_uri': 'spotify:track:3E5NxItWJmrd4I6ddpePZr', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629449607, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T18:59:02Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 241173, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Porcelain', 'master_metadata_album_artist_name': 'Moby', 'master_metadata_album_album_name': 'Play & Play: B Sides', 'spotify_track_uri': 'spotify:track:2UKYMN7VnsQo40n0qCt6Sa', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629700285, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:03:16Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 253586, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Enjoy the Silence', 'master_metadata_album_artist_name': 'Depeche Mode', 'master_metadata_album_album_name': 'The Best of Depeche Mode, Vol. 1 (Deluxe)', 'spotify_track_uri': 'spotify:track:0ULPav7qqKTHn7vgi9v42k', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485629942004, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:09:18Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 360733, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'It Hurts Me So', 'master_metadata_album_artist_name': 'Jay-Jay Johanson', 'master_metadata_album_album_name': 'Whiskey', 'spotify_track_uri': 'spotify:track:1BLSuWtTmTTAjqzfXUHlQp', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485630196009, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:11:22Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 122870, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'High Hopes', 'master_metadata_album_artist_name': 'Pink Floyd', 'master_metadata_album_album_name': 'The Division Bell', 'spotify_track_uri': 'spotify:track:5a4MgIUSf9K8wXLSm6xPEx', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485630557269, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:11:25Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 2530, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Zombie', 'master_metadata_album_artist_name': 'The Cranberries', 'master_metadata_album_album_name': 'No Need To Argue (The Complete Sessions 1994-1995)', 'spotify_track_uri': 'spotify:track:6xy6jNeNTYwjnKTDzMyHw2', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485630681575, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:11:27Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 2182, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Clocks', 'master_metadata_album_artist_name': 'Coldplay', 'master_metadata_album_album_name': 'A Rush of Blood to the Head', 'spotify_track_uri': 'spotify:track:0BCPKOYdS2jbQ8iyB56Zns', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485630684158, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:15:22Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 236200, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Army Of Me', 'master_metadata_album_artist_name': 'Björk', 'master_metadata_album_album_name': 'Post', 'spotify_track_uri': 'spotify:track:2AS1h6NKoBzCoxlnmddOjI', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485630686352, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:21:19Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 356426, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Trains', 'master_metadata_album_artist_name': 'Porcupine Tree', 'master_metadata_album_album_name': 'In Absentia', 'spotify_track_uri': 'spotify:track:21g7QVCF7OFqniIIOANiVY', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485630921666, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:26:20Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 300295, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'You Know, You Know', 'master_metadata_album_artist_name': 'John McLaughlin', 'master_metadata_album_album_name': 'The Inner Mounting Flame', 'spotify_track_uri': 'spotify:track:0KBjFrKkWhJMjdLX1wBgzg', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1485631278551, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:35:02Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 522000, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'En la Ciudad de la Furia - MTV Unplugged', 'master_metadata_album_artist_name': 'Soda Stereo', 'master_metadata_album_album_name': 'Comfort Y Musica Para Volar', 'spotify_track_uri': 'spotify:track:2p4FOWHHd2A6TBmTkdt1G0', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'clickrow', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485631580714, 'incognito_mode': False}
# registro enviado: {'ts': '2017-01-28T19:39:37Z', 'username': '12135236562', 'platform': 'iOS 10.2 (iPhone8,1)', 'ms_played': 274586, 'conn_country': 'CL', 'ip_addr_decrypted': None, 'user_agent_decrypted': None, 'master_metadata_track_name': 'Un Misil En Mi Placard - MTV Unplugged', 'master_metadata_album_artist_name': 'Soda Stereo', 'master_metadata_album_album_name': 'Comfort Y Musica Para Volar', 'spotify_track_uri': 'spotify:track:7IJC1qatyg2t8SZiwJRvID', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': None, 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1485632102079, 'incognito_mode': False}
# File data sent, closing connection.

# %%
import socket
import time
import json

def start_server(file_path, host, port, delay):
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as server_socket:
        server_socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
        server_socket.bind((host, port))
        server_socket.listen(1)
        print(f"Server listening on {host}:{port}")
        conn, addr = server_socket.accept()
        with conn:
            print(f"Connected by {addr}") 
            with open(file_path, 'r') as file: 
                #json_file = json.load(file) 
                for line in file:
                    if line.strip()!= '':
                        conn.sendall(line.encode())
                        print(f"registro enviado: {line}")  
                        time.sleep(delay) 
            print("File data sent, closing connection.")
            conn.close()

host = 'localhost'
port = 9999
delay = 1
file_path = 'data/streaming/Don-Quijote.txt'

start_server(file_path, host, port, delay)
# Out:
# Server listening on localhost:9999
# Connected by ('127.0.0.1', 58597)
# registro enviado: ﻿El ingenioso hidalgo don Quijote de la Mancha
#
# registro enviado: por Miguel de Cervantes Saavedra
#
# registro enviado: El ingenioso hidalgo don Quijote de la Mancha
#
# registro enviado: Tasa
#
# registro enviado: Testimonio de las erratas
#
# registro enviado: El Rey
#
# registro enviado: Al Duque de Béjar
#
# registro enviado: Prólogo
#
# registro enviado: Al libro de don Quijote de la Mancha
#
# registro enviado: Que trata de la condición y ejercicio del famoso
#
# registro enviado: hidalgo don Quijote de la Mancha
#
# registro enviado: Que trata de la primera salida que de su tierra hizo
#
# registro enviado: el ingenioso don Quijote
#
# registro enviado: Donde se cuenta la graciosa manera que tuvo don
#
# registro enviado: Quijote en armarse caballero
#
# registro enviado: De lo que le sucedió a nuestro caballero cuando salió
#
# registro enviado: de la venta
#
# registro enviado: Donde se prosigue la narración de la desgracia de
#
# registro enviado: nuestro caballero
#
# registro enviado: Del donoso y grande escrutinio que el cura y el
#
# registro enviado: barbero hicieron en la librería de nuestro ingenioso hidalgo
#
# registro enviado: De la segunda salida de nuestro buen caballero don
#
# registro enviado: Quijote de la Mancha
#
# registro enviado: Del buen suceso que el valeroso don Quijote tuvo en
#
# registro enviado: la espantable y jamás imaginada aventura de los molinos de viento, con
#
# registro enviado: otros sucesos dignos de felice recordación
#
# registro enviado: Donde se concluye y da fin a la estupenda batalla que
#
# registro enviado: el gallardo vizcaíno y el valiente manchego tuvieron
#
# registro enviado: De lo que más le avino a don Quijote con el vizcaíno, y
#
# registro enviado: del peligro en que se vio con una turba de yangüeses
#
# registro enviado: De lo que le sucedió a don Quijote con unos
#
# registro enviado: cabreros
#
# registro enviado: De lo que contó un cabrero a los que estaban con don
#
# registro enviado: Quijote
#
# registro enviado: Donde se da fin al cuento de la pastora Marcela, con
#
# registro enviado: otros sucesos
#
# registro enviado: Donde se ponen los versos desesperados del difunto
#
# registro enviado: pastor, con otros no esperados sucesos
#
# registro enviado: Donde se cuenta la desgraciada aventura que se topó
#
# registro enviado: don Quijote en topar con unos desalmados yangüeses
#
# registro enviado: De lo que le sucedió al ingenioso hidalgo en la venta
#
# registro enviado: que él imaginaba ser castillo
#
# registro enviado: Donde se prosiguen los innumerables trabajos que el
#
# registro enviado: bravo don Quijote y su buen escudero Sancho Panza pasaron en la venta
#
# registro enviado: que, por su mal, pensó que era castillo
#
# registro enviado: Donde se cuentan las razones que pasó Sancho Panza
#
# registro enviado: con su señor Don Quijote, con otras aventuras dignas de ser
#
# registro enviado: contadas
#
# registro enviado: De las discretas razones que Sancho pasaba con su
#
# registro enviado: amo, y de la aventura que le sucedió con un cuerpo muerto, con otros
#
# registro enviado: acontecimientos famosos
#
# registro enviado: De la jamás vista ni oída aventura que con más poco
#
# registro enviado: peligro fue acabada de famoso caballero en el mundo, como la que acabó
#
# registro enviado: el valeroso don Quijote de la Mancha
#
# registro enviado: Que trata de la alta aventura y rica ganancia del
#
# registro enviado: yelmo de Mambrino, con otras cosas sucedidas a nuestro invencible
#
# registro enviado: caballero
#
# registro enviado: De la libertad que dio don Quijote a muchos
#
# registro enviado: desdichados que, mal de su grado, los llevaban donde no quisieran
#
# registro enviado: ir
#
# registro enviado: De lo que le aconteció al famoso don Quijote en
#
# registro enviado: Sierra Morena, que fue una de las más raras aventuras que en esta
#
# registro enviado: verdadera historia se cuentan
#
# registro enviado: Donde se prosigue la aventura de la Sierra
#
# registro enviado: Morena
#
# registro enviado: Que trata de las estrañas cosas que en Sierra Morena
#
# registro enviado: sucedieron al valiente caballero de la Mancha, y de la imitación que
#
# registro enviado: hizo a la penitencia de Beltenebros
#
# registro enviado: Donde se prosiguen las finezas que de enamorado hizo
#
# registro enviado: don Quijote en Sierra Morena
#
# registro enviado: De cómo salieron con su intención el cura y el
#
# registro enviado: barbero, con otras cosas dignas de que se cuenten en esta grande
#
# registro enviado: historia
#
# registro enviado: Que trata de la nueva y agradable aventura que al
#
# registro enviado: cura y barbero sucedió en la mesma sierra
#
# registro enviado: Que trata de la discreción de la hermosa Dorotea,
#
# registro enviado: con otras cosas de mucho gusto y pasatiempo
#
# registro enviado: Que trata del gracioso artificio y orden que se tuvo
#
# registro enviado: en sacar a nuestro enamorado caballero de la asperísima penitencia en
#
# registro enviado: que se había puesto
#
# registro enviado: De los sabrosos razonamientos que pasaron entre don
#
# registro enviado: Quijote y Sancho Panza, su escudero, con otros sucesos
#
# registro enviado: Que trata de lo que sucedió en la venta a toda la
#
# registro enviado: cuadrilla de don Quijote
#
# registro enviado: Donde se cuenta la novela del Curioso
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 29
#      26 delay = 1
#      27 file_path = 'data/streaming/Don-Quijote.txt'
# ---> 29 start_server(file_path, host, port, delay)
#
# Cell In[21], line 20, in start_server(file_path, host, port, delay)
#      18             conn.sendall(line.encode())
#      19             print(f"registro enviado: {line}")
# ---> 20             time.sleep(delay)
#      21 print("File data sent, closing connection.")
#      22 conn.close()
#
# KeyboardInterrupt:
